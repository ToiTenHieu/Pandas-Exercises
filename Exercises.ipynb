# %% [markdown]
# <a href="https://colab.research.google.com/github/ToiTenHieu/Pandas-Exercises/blob/00_Creating_Series_and_DataFrames/Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pokemon

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
pokemon = pd.read_csv("pokemon.csv")

# %% [markdown]
# ### Step 2. Create a data dictionary that looks like the DataFrame below

# %%
pokemon = pd.DataFrame({
    "name": pokemon["Name"],
    "type": pokemon["Type 1"],
    "hp": pokemon["HP"],
    "evolution": "Unknown",
    "pokedex": pokemon["#"]
})

# %% [markdown]
# ### Step 3. Assign it to a variable called pokemon

# %%
# Out:
#     evolution  hp        name pokedex   type
# 0     Ivysaur  45   Bulbasaur     yes  grass
# 1  Charmeleon  39  Charmander      no   fire
# 2   Wartortle  44    Squirtle     yes  water
# 3     Metapod  45    Caterpie      no    bug

# %% [markdown]
# ### Step 4. Ops...it seems the DataFrame columns are in alphabetical order. Place  the order of the columns as name, type, hp, evolution, pokedex

# %%
pokemon = pokemon[["name", "type", "hp", "evolution", "pokedex"]]

# %% [markdown]
# ### Step 5. Add another column called place, and insert what you have in mind.

# %%
pokemon["place"] = "Pokemon World"

# %% [markdown]
# ### Step 6. Present the type of each column

# %%
print("\nData Types:")
print(pokemon.dtypes)
# Out:
# Data Types:
# name         object
# type         object
# hp            int64
# evolution    object
# pokedex       int64
# place        object
# dtype: object

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
max_hp = pokemon.loc[pokemon["hp"].idxmax()]

print("\nPokemon with highest HP:")
print(max_hp)
# Out:
# Pokemon with highest HP:
# name               Blissey
# type                Normal
# hp                     255
# evolution          Unknown
# pokedex                242
# place        Pokemon World
# Name: 261, dtype: object
